# %%
import numpy as np
import pandas as pd

# %%
laptops = pd.read_csv("laptops.csv", encoding = "Latin-1")

# %%
laptops.shape
# Out:
# (1303, 13)

# %%
laptops.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
laptops.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price (Euros)'],
#       dtype='object')

# %%
list(laptops.index[:7])
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
laptops.columns = laptops.columns.str.lower().str.strip().str.replace('operating system',"os").str.replace(" ","_")

# %%
laptops.columns = laptops.columns.str.replace("(", "").str.replace(")", "")

# %%
laptops.columns
# Out:
# Index(['manufacturer', 'model_name', 'category', 'screen_size', 'screen',
#        'cpu', 'ram', 'storage', 'gpu', 'os', 'os_version', 'weight',
#        'price_euros'],
#       dtype='object')

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  1303 non-null   object
#  1   model_name    1303 non-null   object
#  2   category      1303 non-null   object
#  3   screen_size   1303 non-null   object
#  4   screen        1303 non-null   object
#  5   cpu           1303 non-null   object
#  6   ram           1303 non-null   object
#  7   storage       1303 non-null   object
#  8   gpu           1303 non-null   object
#  9   os            1303 non-null   object
#  10  os_version    1133 non-null   object
#  11  weight        1303 non-null   object
#  12  price_euros   1303 non-null   object
# dtypes: object(13)
# memory usage: 132.5+ KB

# %%
laptops["screen_size"] = laptops["screen_size"].str.strip('"').astype(float)

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  1303 non-null   object
#  1   model_name    1303 non-null   object
#  2   category      1303 non-null   object
#  3   screen_size   1303 non-null   float64
#  4   screen        1303 non-null   object
#  5   cpu           1303 non-null   object
#  6   ram           1303 non-null   object
#  7   storage       1303 non-null   object
#  8   gpu           1303 non-null   object
#  9   os            1303 non-null   object
#  10  os_version    1133 non-null   object
#  11  weight        1303 non-null   object
#  12  price_euros   1303 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 132.5+ KB

# %%
laptops.head()
# Out:
#   manufacturer   model_name   category  screen_size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                screen                         cpu   ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                storage                           gpu     os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS        NaN
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS        NaN
# ...

# %%
laptops.rename({"screen_size":"screen_size_inches" }, axis = 1, inplace = True)

# %%
laptops.head()
# Out:
#   manufacturer   model_name   category  screen_size_inches  \
# 0        Apple  MacBook Pro  Ultrabook                13.3
# 1        Apple  Macbook Air  Ultrabook                13.3
# 2           HP       250 G6   Notebook                15.6
# 3        Apple  MacBook Pro  Ultrabook                15.4
# 4        Apple  MacBook Pro  Ultrabook                13.3
#
#                                screen                         cpu   ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                storage                           gpu     os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS        NaN
# ...

# %%
# laptops.rename({0:"Waqas"}, axis = 0).head()

# %%
laptops.head()
# Out:
#   manufacturer   model_name   category  screen_size_inches  \
# 0        Apple  MacBook Pro  Ultrabook                13.3
# 1        Apple  Macbook Air  Ultrabook                13.3
# 2           HP       250 G6   Notebook                15.6
# 3        Apple  MacBook Pro  Ultrabook                15.4
# 4        Apple  MacBook Pro  Ultrabook                13.3
#
#                                screen                         cpu   ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                storage                           gpu     os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS        NaN
# ...

# %%
laptops["os"].value_counts()
# Out:
# Windows      1125
# No OS          66
# Linux          62
# Chrome OS      27
# macOS          13
# Mac OS          8
# Android         2
# Name: os, dtype: int64

# %%
laptops["os"].unique()
# Out:
# array(['macOS', 'No OS', 'Windows', 'Mac OS', 'Linux', 'Android',
#        'Chrome OS'], dtype=object)

# %%
# laptops["os"] = laptops["os"].str.replace("Mac OS","macOS")

# %%
d = {'macOS':'macOS', 'No OS':'No OS', 'Windows':'Windows', 'Mac OS':'macOS', 'Android':'Android',
       'Chrome OS':'Chrome OS'}

laptops["os"] = laptops["os"].map(d)

# %%
laptops["os"].unique()
# Out:
# array(['macOS', 'No OS', 'Windows', nan, 'Android', 'Chrome OS'],
#       dtype=object)

# %%
d = {'macOS':'macOS', 'No OS':'No OS', 'Windows':'Windows', 'Mac OS':'macOS', 'Android':'Android',
       'Chrome OS':'Chrome OS', np.nan:"Linux"}

laptops["os"] = laptops["os"].map(d)

# %%
laptops["os"].unique()
# Out:
# array(['macOS', 'No OS', 'Windows', 'Linux', 'Android', 'Chrome OS'],
#       dtype=object)

# %%
laptops["cpu"].head()
# Out:
# 0          Intel Core i5 2.3GHz
# 1          Intel Core i5 1.8GHz
# 2    Intel Core i5 7200U 2.5GHz
# 3          Intel Core i7 2.7GHz
# 4          Intel Core i5 3.1GHz
# Name: cpu, dtype: object

# %%
laptops["cpu_manufacturer"] = 0

# %%
laptops.head()
# Out:
#   manufacturer   model_name   category  screen_size_inches  \
# 0        Apple  MacBook Pro  Ultrabook                13.3
# 1        Apple  Macbook Air  Ultrabook                13.3
# 2           HP       250 G6   Notebook                15.6
# 3        Apple  MacBook Pro  Ultrabook                15.4
# 4        Apple  MacBook Pro  Ultrabook                13.3
#
#                                screen                         cpu   ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                storage                           gpu     os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS        NaN
# ...

# %%
laptops["cpu_manufacturer"] = laptops["cpu"].str.split().str[0]

# %%
laptops.head(10)
# Out:
#   manufacturer       model_name   category  screen_size_inches  \
# 0        Apple      MacBook Pro  Ultrabook                13.3
# 1        Apple      Macbook Air  Ultrabook                13.3
# 2           HP           250 G6   Notebook                15.6
# 3        Apple      MacBook Pro  Ultrabook                15.4
# 4        Apple      MacBook Pro  Ultrabook                13.3
# 5         Acer         Aspire 3   Notebook                15.6
# 6        Apple      MacBook Pro  Ultrabook                15.4
# 7        Apple      Macbook Air  Ultrabook                13.3
# 8         Asus  ZenBook UX430UN  Ultrabook                14.0
# 9         Acer          Swift 3  Ultrabook                14.0
#
#                                screen                         cpu   ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# ...

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   manufacturer        1303 non-null   object
#  1   model_name          1303 non-null   object
#  2   category            1303 non-null   object
#  3   screen_size_inches  1303 non-null   float64
#  4   screen              1303 non-null   object
#  5   cpu                 1303 non-null   object
#  6   ram                 1303 non-null   object
#  7   storage             1303 non-null   object
#  8   gpu                 1303 non-null   object
#  9   os                  1303 non-null   object
#  10  os_version          1133 non-null   object
#  11  weight              1303 non-null   object
#  12  price_euros         1303 non-null   object
#  13  cpu_manufacturer    1303 non-null   object
# dtypes: float64(1), object(13)
# memory usage: 142.6+ KB

# %%
laptops.isnull().sum()
# Out:
# manufacturer            0
# model_name              0
# category                0
# screen_size_inches      0
# screen                  0
# cpu                     0
# ram                     0
# storage                 0
# gpu                     0
# os                      0
# os_version            170
# weight                  0
# price_euros             0
# cpu_manufacturer        0
# dtype: int64

# %%
n = laptops["os_version"].isnull()

laptops[n]
# Out:
#      manufacturer      model_name   category  screen_size_inches  \
# 0           Apple     MacBook Pro  Ultrabook                13.3
# 1           Apple     Macbook Air  Ultrabook                13.3
# 2              HP          250 G6   Notebook                15.6
# 3           Apple     MacBook Pro  Ultrabook                15.4
# 4           Apple     MacBook Pro  Ultrabook                13.3
# ...           ...             ...        ...                 ...
# 1267         Dell   Inspiron 3567   Notebook                15.6
# 1277         Acer  Aspire ES1-531   Notebook                15.6
# 1281         Dell   Inspiron 3567   Notebook                15.6
# 1291         Acer  Aspire ES1-531   Notebook                15.6
# 1295         Dell   Inspiron 3567   Notebook                15.6
#
#                                   screen  \
# 0     IPS Panel Retina Display 2560x1600
# 1                               1440x900
# 2                      Full HD 1920x1080
# ...

# %%
laptops[n]["os"].unique()
# Out:
# array(['macOS', 'No OS', 'Linux', 'Android', 'Chrome OS'], dtype=object)

# %%
laptops[laptops["os"] == 'macOS']
# Out:
#      manufacturer   model_name   category  screen_size_inches  \
# 0           Apple  MacBook Pro  Ultrabook                13.3
# 1           Apple  Macbook Air  Ultrabook                13.3
# 3           Apple  MacBook Pro  Ultrabook                15.4
# 4           Apple  MacBook Pro  Ultrabook                13.3
# 6           Apple  MacBook Pro  Ultrabook                15.4
# 7           Apple  Macbook Air  Ultrabook                13.3
# 12          Apple  MacBook Pro  Ultrabook                15.4
# 14          Apple  MacBook 12"  Ultrabook                12.0
# 15          Apple  MacBook Pro  Ultrabook                13.3
# 17          Apple  MacBook Pro  Ultrabook                15.4
# 26          Apple  MacBook Air  Ultrabook                13.3
# 34          Apple  MacBook Air  Ultrabook                13.3
# 45          Apple  MacBook Pro  Ultrabook                13.3
# 81          Apple  MacBook 12"  Ultrabook                12.0
# ...

# %%
# laptops[laptops["os_version"].isnull()]

laptops.loc[laptops["os"]=="macOS","os_version"] = "X"

# %%
laptops[laptops["os"]=="macOS"]
# Out:
#      manufacturer   model_name   category  screen_size_inches  \
# 0           Apple  MacBook Pro  Ultrabook                13.3
# 1           Apple  Macbook Air  Ultrabook                13.3
# 3           Apple  MacBook Pro  Ultrabook                15.4
# 4           Apple  MacBook Pro  Ultrabook                13.3
# 6           Apple  MacBook Pro  Ultrabook                15.4
# 7           Apple  Macbook Air  Ultrabook                13.3
# 12          Apple  MacBook Pro  Ultrabook                15.4
# 14          Apple  MacBook 12"  Ultrabook                12.0
# 15          Apple  MacBook Pro  Ultrabook                13.3
# 17          Apple  MacBook Pro  Ultrabook                15.4
# 26          Apple  MacBook Air  Ultrabook                13.3
# 34          Apple  MacBook Air  Ultrabook                13.3
# 45          Apple  MacBook Pro  Ultrabook                13.3
# 81          Apple  MacBook 12"  Ultrabook                12.0
# ...

# %%
laptops.loc[laptops["os"]=='No OS',"os_version"] = "Version Unknown"

# %%
n = laptops["os_version"].isnull()

laptops[n]
# Out:
#      manufacturer                                    model_name  \
# 36           Acer                                      Aspire 3
# 40           Asus     X540UA-DM186 (i3-6006U/4GB/1TB/FHD/Linux)
# 42           Asus        X542UQ-GO005 (i5-7200U/8GB/1TB/GeForce
# 50         Lenovo                                     Yoga Book
# 59           Asus  X541UA-DM1897 (i3-6006U/4GB/256GB/FHD/Linux)
# ...           ...                                           ...
# 1267         Dell                                 Inspiron 3567
# 1277         Acer                                Aspire ES1-531
# 1281         Dell                                 Inspiron 3567
# 1291         Acer                                Aspire ES1-531
# 1295         Dell                                 Inspiron 3567
#
#                 category  screen_size_inches                           screen  \
# 36              Notebook                15.6                         1366x768
# ...

# %%
laptops.isnull().sum()
# Out:
# manufacturer           0
# model_name             0
# category               0
# screen_size_inches     0
# screen                 0
# cpu                    0
# ram                    0
# storage                0
# gpu                    0
# os                     0
# os_version            91
# weight                 0
# price_euros            0
# cpu_manufacturer       0
# dtype: int64

# %%
laptops[n]["os"].unique()
# Out:
# array(['Linux', 'Android', 'Chrome OS'], dtype=object)
